# %% [markdown]
# <a href="https://colab.research.google.com/github/RasikhTariq/machinelearning/blob/main/TitanicSurvivalPredictionUsingML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

file_path = '/content/drive/MyDrive/Colab Notebooks/2025-Module 1. Activity 1. Introduction to Machine Learning/Titanic-Dataset.xlsx'

df = pd.read_excel(file_path)

df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df = df.drop(columns=['PassengerId', 'Name', 'Ticket', 'Cabin'])

df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %% [markdown]
# The details of the variables is available on the link: https://www.kaggle.com/c/titanic/data
#
# survival: Survival	0 = No, 1 = Yes
#
# pclass:	Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd
#
# sex:	Sex
#
# Age:	Age in years
#
# sibsp:	# of siblings / spouses aboard the Titanic
#
# parch:	# of parents / children aboard the Titanic
#
# fare:	Passenger fare
#
# embarked	Port of Embarkation	C = Cherbourg, Q = Queenstown, S = Southampton

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Embarked     object
# dtype: object

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
import pandas as pd
import plotly.express as px

# Prepare the data
df['Survival Status'] = df['Survived'].map({0: 'Did Not Survive', 1: 'Survived'})
df['Class'] = df['Pclass'].map({1: 'First Class', 2: 'Second Class', 3: 'Third Class'})

# Create interactive bar chart
fig = px.histogram(
    df,
    x='Class',
    color='Survival Status',
    barmode='group',
    title='🧭 Titanic Survival by Passenger Class',
    labels={'Class': 'Passenger Class', 'count': 'Number of Passengers'},
    color_discrete_map={'Survived': '#1f77b4', 'Did Not Survive': '#ff7f0e'},
    category_orders={'Class': ['First Class', 'Second Class', 'Third Class']}
)

# Customize layout for clarity
fig.update_layout(
    xaxis_title='Passenger Class',
    yaxis_title='Number of Passengers',
    legend_title='Survival Status',
    bargap=0.2,
    template='plotly_white',
    title_x=0.5,
    font=dict(size=14)
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px

# Assuming df is your Titanic DataFrame
# Map survival values to meaningful labels
df['Survival Status'] = df['Survived'].map({0: 'Did Not Survive', 1: 'Survived'})

# Remove rows with missing age for cleaner visualization
df_age = df.dropna(subset=['Age'])

# Create interactive histogram (density-type distribution)
fig = px.histogram(
    df_age,
    x='Age',
    color='Survival Status',
    nbins=40,
    barmode='overlay',
    histnorm='percent',
    title='🎯 Age Distribution of Titanic Passengers by Survival Status',
    labels={'Age': 'Age of Passenger', 'count': 'Percentage'},
    color_discrete_map={'Survived': '#1f77b4', 'Did Not Survive': '#ff7f0e'}
)

# Customize layout
fig.update_layout(
    bargap=0.1,
    template='plotly_white',
    title_x=0.5,
    font=dict(size=14),
    legend_title='Survival Status',
    xaxis_title='Age',
    yaxis_title='Percentage of Passengers'
)

# Display the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_encoded = pd.get_dummies(df, columns=['Sex', 'Embarked'], drop_first=True)

df_encoded
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  Survival Status  Sex_male  \
# 0           0       3  22.0      1      0   7.2500  Did Not Survive      True
# 1           1       1  38.0      1      0  71.2833         Survived     False
# 2           1       3  26.0      0      0   7.9250         Survived     False
# 3           1       1  35.0      1      0  53.1000         Survived     False
# 4           0       3  35.0      0      0   8.0500  Did Not Survive      True
# ..        ...     ...   ...    ...    ...      ...              ...       ...
# 886         0       2  27.0      0      0  13.0000  Did Not Survive      True
# 887         1       1  19.0      0      0  30.0000         Survived     False
# 888         0       3   NaN      1      2  23.4500  Did Not Survive     False
# 889         1       1  26.0      0      0  30.0000         Survived      True
# 890         0       3  32.0      0      0   7.7500  Did Not Survive      True
#
#      Embarked_Q  Embarked_S
# ...

# %%
df_encoded.dtypes
# Out:
# Survived             int64
# Pclass               int64
# Age                float64
# SibSp                int64
# Parch                int64
# Fare               float64
# Survival Status     object
# Sex_male              bool
# Embarked_Q            bool
# Embarked_S            bool
# dtype: object

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
missing_data = df_encoded.isnull().sum()

missing_data[missing_data > 0]
# Out:
# Age    177
# dtype: int64

# %%
df_encoded['Age'].fillna(df_encoded['Age'].mean(), inplace=True)
# Out:
# <ipython-input-45-bdb551ff9e8e>:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
missing_data = df_encoded.isnull().sum()

missing_data[missing_data > 0]
# Out:
# Series([], dtype: int64)

# %%
df_encoded
# Out:
#      Survived  Pclass        Age  SibSp  Parch     Fare  Survival Status  \
# 0           0       3  22.000000      1      0   7.2500  Did Not Survive
# 1           1       1  38.000000      1      0  71.2833         Survived
# 2           1       3  26.000000      0      0   7.9250         Survived
# 3           1       1  35.000000      1      0  53.1000         Survived
# 4           0       3  35.000000      0      0   8.0500  Did Not Survive
# ..        ...     ...        ...    ...    ...      ...              ...
# 886         0       2  27.000000      0      0  13.0000  Did Not Survive
# 887         1       1  19.000000      0      0  30.0000         Survived
# 888         0       3  29.699118      1      2  23.4500  Did Not Survive
# 889         1       1  26.000000      0      0  30.0000         Survived
# 890         0       3  32.000000      0      0   7.7500  Did Not Survive
#
#      Sex_male  Embarked_Q  Embarked_S
# 0        True       False        True
# ...

# %%
df_encoded.drop(columns=['Survival Status'], inplace=True)

# %%
df_encoded.dtypes
# Out:
# Survived        int64
# Pclass          int64
# Age           float64
# SibSp           int64
# Parch           int64
# Fare          float64
# Sex_male         bool
# Embarked_Q       bool
# Embarked_S       bool
# dtype: object

# %%
df_encoded
# Out:
#      Survived  Pclass        Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  \
# 0           0       3  22.000000      1      0   7.2500      True       False
# 1           1       1  38.000000      1      0  71.2833     False       False
# 2           1       3  26.000000      0      0   7.9250     False       False
# 3           1       1  35.000000      1      0  53.1000     False       False
# 4           0       3  35.000000      0      0   8.0500      True       False
# ..        ...     ...        ...    ...    ...      ...       ...         ...
# 886         0       2  27.000000      0      0  13.0000      True       False
# 887         1       1  19.000000      0      0  30.0000     False       False
# 888         0       3  29.699118      1      2  23.4500     False       False
# 889         1       1  26.000000      0      0  30.0000      True       False
# 890         0       3  32.000000      0      0   7.7500      True        True
#
#      Embarked_S
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

X = df_encoded.drop(columns='Survived')
y = df_encoded['Survived']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

clf = DecisionTreeClassifier(random_state=42)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print("Accuracy on Test Set:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy on Test Set: 0.7313432835820896
#
# Confusion Matrix:
#  [[123  34]
#  [ 38  73]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77       157
#            1       0.68      0.66      0.67       111
#
#     accuracy                           0.73       268
#    macro avg       0.72      0.72      0.72       268
# weighted avg       0.73      0.73      0.73       268

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import pandas as pd
import plotly.express as px

# Define features and target
X = df_encoded.drop(columns='Survived')
y = df_encoded['Survived']

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Decision Tree
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

# Predict on test set
y_pred = clf.predict(X_test)

# Evaluate model
print("Accuracy on Test Set:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# ---- Feature Relevance Section ----

# Extract feature importances
importances_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': clf.feature_importances_
}).sort_values(by='Importance', ascending=False)

# Plot interactive feature importance chart
fig = px.bar(importances_df,
             x='Importance',
             y='Feature',
             orientation='h',
             title='Decision Tree - Feature Relevance',
             labels={'Importance': 'Importance Score', 'Feature': 'Features'},
             text='Importance')

fig.update_traces(texttemplate='%{text:.3f}', textposition='outside')
fig.update_layout(yaxis={'categoryorder': 'total ascending'},
                  xaxis=dict(showgrid=True),
                  plot_bgcolor='white')

fig.show()
# Out:
# Accuracy on Test Set: 0.7313432835820896
#
# Confusion Matrix:
#  [[123  34]
#  [ 38  73]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77       157
#            1       0.68      0.66      0.67       111
#
#     accuracy                           0.73       268
#    macro avg       0.72      0.72      0.72       268
# weighted avg       0.73      0.73      0.73       268
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Create a DataFrame for feature importances
importances_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': clf.feature_importances_
}).sort_values(by='Importance', ascending=False)

# Plot interactive feature importance chart using Plotly
import plotly.express as px

fig = px.bar(importances_df,
             x='Importance',
             y='Feature',
             orientation='h',
             title='Decision Tree - Feature Importances',
             labels={'Importance': 'Importance Score', 'Feature': 'Features'},
             text='Importance')

fig.update_traces(texttemplate='%{text:.3f}', textposition='outside')
fig.update_layout(yaxis={'categoryorder': 'total ascending'},
                  xaxis=dict(showgrid=True),
                  plot_bgcolor='white')

fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-ce72fd720fcf> in <cell line: 0>()
#       2 importances_df = pd.DataFrame({
#       3     'Feature': X.columns,
# ----> 4     'Importance': clf.feature_importances_
#       5 }).sort_values(by='Importance', ascending=False)
#       6
#
# AttributeError: 'KNeighborsClassifier' object has no attribute 'feature_importances_'

# %%
# Show feature importances
import pandas as pd
pd.Series(clf.feature_importances_, index=X.columns).sort_values(ascending=False)
# Out:
# Sex_male      0.298013
# Fare          0.243179
# Age           0.225433
# Pclass        0.109462
# SibSp         0.056437
# Embarked_S    0.030490
# Parch         0.023001
# Embarked_Q    0.013985
# dtype: float64

# %%
import plotly.express as px
import pandas as pd

# Create a DataFrame from feature importances
importances_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': clf.feature_importances_
}).sort_values(by='Importance', ascending=False)

# Plot using Plotly
fig = px.bar(importances_df,
             x='Importance',
             y='Feature',
             orientation='h',
             title='Interactive Feature Importances',
             labels={'Importance': 'Importance Score', 'Feature': 'Features'},
             text='Importance')

fig.update_traces(texttemplate='%{text:.3f}', textposition='outside')
fig.update_layout(yaxis={'categoryorder':'total ascending'},
                  xaxis=dict(showgrid=True),
                  plot_bgcolor='white')

fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-75d947ecf4b8> in <cell line: 0>()
#       5 importances_df = pd.DataFrame({
#       6     'Feature': X.columns,
# ----> 7     'Importance': clf.feature_importances_
#       8 }).sort_values(by='Importance', ascending=False)
#       9
#
# AttributeError: 'KNeighborsClassifier' object has no attribute 'feature_importances_'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Define features and target
X = df_encoded.drop(columns='Survived')
y = df_encoded['Survived']

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Instantiate Random Forest classifier
clf = RandomForestClassifier(random_state=42, n_estimators=100)

# Train model
clf.fit(X_train, y_train)

# Predict on test set
y_pred = clf.predict(X_test)

# Evaluation
print("Accuracy on Test Set:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy on Test Set: 0.7985074626865671
#
# Confusion Matrix:
#  [[135  22]
#  [ 32  79]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83       157
#            1       0.78      0.71      0.75       111
#
#     accuracy                           0.80       268
#    macro avg       0.80      0.79      0.79       268
# weighted avg       0.80      0.80      0.80       268

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Define features and target
X = df_encoded.drop(columns='Survived')
y = df_encoded['Survived']

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Instantiate Support Vector Classifier
clf = SVC(kernel='rbf', random_state=42)

# Train model
clf.fit(X_train, y_train)

# Predict on test set
y_pred = clf.predict(X_test)

# Evaluation
print("Accuracy on Test Set:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy on Test Set: 0.6604477611940298
#
# Confusion Matrix:
#  [[148   9]
#  [ 82  29]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.94      0.76       157
#            1       0.76      0.26      0.39       111
#
#     accuracy                           0.66       268
#    macro avg       0.70      0.60      0.58       268
# weighted avg       0.69      0.66      0.61       268

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler

# Define features and target
X = df_encoded.drop(columns='Survived')
y = df_encoded['Survived']

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Normalize the data for KNN (important for distance-based algorithms)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Instantiate KNN classifier (k=5 by default)
clf = KNeighborsClassifier(n_neighbors=5)

# Train model
clf.fit(X_train, y_train)

# Predict on test set
y_pred = clf.predict(X_test)

# Evaluation
print("Accuracy on Test Set:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy on Test Set: 0.7910447761194029
#
# Confusion Matrix:
#  [[137  20]
#  [ 36  75]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83       157
#            1       0.79      0.68      0.73       111
#
#     accuracy                           0.79       268
#    macro avg       0.79      0.77      0.78       268
# weighted avg       0.79      0.79      0.79       268
